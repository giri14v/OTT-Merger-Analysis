# %%
import mysql.connector
import pandas as pd

jotstar_db = mysql.connector.connect(
      host="127.0.0.1",
      user="root",
      password="Giri@14102003",
      database="jotstar_db"
    )

liocinema_db = mysql.connector.connect(
      host="127.0.0.1",
      user="root",
      password="Giri@14102003",
      database="liocinema_db"
    )

# %%
jotstar_content = "SELECT * from contents"
jotstar_subscribers = "SELECT * from subscribers"
jotstar_content_consumption = "SELECT * from content_consumption"

# %%
jotstar_content_df = pd.read_sql(jotstar_content, jotstar_db)
jotstar_subscribers_df = pd.read_sql(jotstar_subscribers, jotstar_db)
jotstar_content_consumption_df = pd.read_sql(jotstar_content_consumption, jotstar_db)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\3828370946.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   jotstar_content_df = pd.read_sql(jotstar_content, jotstar_db)
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\3828370946.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   jotstar_subscribers_df = pd.read_sql(jotstar_subscribers, jotstar_db)
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\3828370946.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
jotstar_db.close()

# %%
jotstar_content_df.head(5)
# Out:
#        content_id content_type language   genre  run_time
# 0  CJSMBEACT2e633        Movie  Bengali  Action        90
# 1  CJSMBEACT34aec        Movie  Bengali  Action       135
# 2  CJSMBEACT83b46        Movie  Bengali  Action       120
# 3  CJSMBECOM12e7a        Movie  Bengali  Comedy       120
# 4  CJSMBECOM5431a        Movie  Bengali  Comedy       135

# %%
jotstar_subscribers_df.head(5)
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
# 2  UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08              Free
# 3  UIDJS00013411a85     35-44    Tier 2        2024-05-31               VIP
# 4  UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20           Premium
#
#   last_active_date plan_change_date new_subscription_plan
# 0             None             None                  None
# 1             None             None                  None
# 2             None             None                  None
# 3             None             None                  None
# 4             None             None                  None

# %%
jotstar_content_consumption_df.head(5)
# Out:
#             user_id device_type  total_watch_time_mins
# 0  UIDJS877cc0e02c9      Mobile                  14613
# 1  UIDJS06384e7ff06      Mobile                  13271
# 2  UIDJSc3997b7beb7      Mobile                   4644
# 3  UIDJS66726ce2325      Mobile                   5734
# 4  UIDJS040119b6107      Mobile                   2939

# %%
liocinema_content = "SELECT * from contents"
liocinema_subscribers = "SELECT * from subscribers"
liocinema_content_consumption = "SELECT * from content_consumption"

# %%
liocinema_content_df = pd.read_sql(liocinema_content, liocinema_db)
liocinema_subscribers_df = pd.read_sql(liocinema_subscribers, liocinema_db)
liocinema_content_consumption_df = pd.read_sql(liocinema_content_consumption, liocinema_db)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\979644006.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   liocinema_content_df = pd.read_sql(liocinema_content, liocinema_db)
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\979644006.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   liocinema_subscribers_df = pd.read_sql(liocinema_subscribers, liocinema_db)
# C:\Users\sanka\AppData\Local\Temp\ipykernel_30368\979644006.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
liocinema_db.close()

# %%
liocinema_content_df.head()
# Out:
#        content_id content_type language   genre  run_time
# 0  CLCMENACT6b77e        Movie  English  Action       120
# 1  CLCMENACTb7ceb        Movie  English  Action       135
# 2  CLCMENCOM1563a        Movie  English  Comedy       135
# 3  CLCMENCOM16d2c        Movie  English  Comedy       135
# 4  CLCMENCOMa0548        Movie  English  Comedy       135

# %%
liocinema_subscribers_df.head()
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDLC00000bea68a     25-34    Tier 3        2024-10-24              Free
# 1  UIDLC00009202848     18-24    Tier 1        2024-09-18             Basic
# 2  UIDLC0001086afc3     35-44    Tier 2        2024-03-23           Premium
# 3  UIDLC000186abd93     18-24    Tier 3        2024-09-07              Free
# 4  UIDLC0002189b09f     18-24    Tier 2        2024-10-07           Premium
#
#   last_active_date plan_change_date new_subscription_plan
# 0             None             None                  None
# 1             None             None                  None
# 2             None       2024-04-23                  Free
# 3       2024-10-23             None                  None
# 4             None       2024-11-07                  Free

# %%
liocinema_content_consumption_df.head()
# Out:
#             user_id device_type  total_watch_time_mins
# 0  UIDLC459c98ee486      Mobile                    502
# 1  UIDLCe4b2fd90790      Mobile                   2098
# 2  UIDLCbc8f0a05367      Mobile                    557
# 3  UIDLC9fc67130445      Mobile                   1720
# 4  UIDLC7026c3e0374      Mobile                    908

# %%
jotstar_content_df.isnull().sum()
# Out:
# content_id      0
# content_type    0
# language        0
# genre           0
# run_time        0
# dtype: int64

# %%
jotstar_subscribers_df.isnull().sum()
# Out:
# user_id                      0
# age_group                    0
# city_tier                    0
# subscription_date            0
# subscription_plan            0
# last_active_date         37968
# plan_change_date         37530
# new_subscription_plan    37530
# dtype: int64

# %% [markdown]
# The null values in the last_active_date, plan_change_date, new_subscription_plan denotes that subscribers are active without changing the subscripition plan

# %%
jotstar_content_consumption_df.isnull().sum()
# Out:
# user_id                  0
# device_type              0
# total_watch_time_mins    0
# dtype: int64

# %%
liocinema_content_df.isnull().sum()
# Out:
# content_id      0
# content_type    0
# language        0
# genre           0
# run_time        0
# dtype: int64

# %%
liocinema_subscribers_df.isnull().sum()
# Out:
# user_id                       0
# age_group                     0
# city_tier                     0
# subscription_date             0
# subscription_plan             0
# last_active_date         101141
# plan_change_date         158432
# new_subscription_plan    158432
# dtype: int64

# %% [markdown]
# The null values in the last_active_date, plan_change_date, new_subscription_plan denotes that subscribers are active without changing the subscripition plan

# %%
liocinema_content_consumption_df.isnull().sum()
# Out:
# user_id                  0
# device_type              0
# total_watch_time_mins    0
# dtype: int64

# %%
jotstar_content_df['platform'] = 'Jotstar'
liocinema_content_df['platform'] = 'LioCinema'

# %%
content_df = pd.concat([liocinema_content_df, jotstar_content_df])

# %%
content_df.head()
# Out:
#        content_id content_type language   genre  run_time   platform
# 0  CLCMENACT6b77e        Movie  English  Action       120  LioCinema
# 1  CLCMENACTb7ceb        Movie  English  Action       135  LioCinema
# 2  CLCMENCOM1563a        Movie  English  Comedy       135  LioCinema
# 3  CLCMENCOM16d2c        Movie  English  Comedy       135  LioCinema
# 4  CLCMENCOMa0548        Movie  English  Comedy       135  LioCinema

# %%
content_df.tail()
# Out:
#           content_id content_type language     genre  run_time platform
# 2355  CJSSTETHR767c0       Series   Telugu  Thriller        20  Jotstar
# 2356  CJSSTETHR8b80e       Series   Telugu  Thriller        30  Jotstar
# 2357  CJSSTETHR92817       Series   Telugu  Thriller        45  Jotstar
# 2358  CJSSTETHRccd4d       Series   Telugu  Thriller        30  Jotstar
# 2359  CJSSTETHRdfb63       Series   Telugu  Thriller        45  Jotstar

# %%
jotstar_subscribers_df['platform'] = 'Jotstar'
liocinema_subscribers_df['platform'] = 'LioCinema'

# %%
subscribers_df = pd.concat([liocinema_subscribers_df, jotstar_subscribers_df])

# %%
subscribers_df.head()
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDLC00000bea68a     25-34    Tier 3        2024-10-24              Free
# 1  UIDLC00009202848     18-24    Tier 1        2024-09-18             Basic
# 2  UIDLC0001086afc3     35-44    Tier 2        2024-03-23           Premium
# 3  UIDLC000186abd93     18-24    Tier 3        2024-09-07              Free
# 4  UIDLC0002189b09f     18-24    Tier 2        2024-10-07           Premium
#
#   last_active_date plan_change_date new_subscription_plan   platform
# 0             None             None                  None  LioCinema
# 1             None             None                  None  LioCinema
# 2             None       2024-04-23                  Free  LioCinema
# 3       2024-10-23             None                  None  LioCinema
# 4             None       2024-11-07                  Free  LioCinema

# %%
subscribers_df.tail()
# Out:
#                 user_id age_group city_tier subscription_date  \
# 44615  UIDJSfffbb38249e     25-34    Tier 2        2024-11-12
# 44616  UIDJSfffbd759005       45+    Tier 1        2024-05-21
# 44617  UIDJSfffebd3002b     25-34    Tier 1        2024-09-27
# 44618  UIDJSffff6698084     35-44    Tier 3        2024-10-12
# 44619  UIDJSffffe298c56     25-34    Tier 2        2024-09-10
#
#       subscription_plan last_active_date plan_change_date  \
# 44615              Free             None             None
# 44616               VIP             None             None
# 44617               VIP       2024-10-29             None
# 44618               VIP             None             None
# 44619              Free             None             None
#
#       new_subscription_plan platform
# 44615                  None  Jotstar
# 44616                  None  Jotstar
# 44617                  None  Jotstar
# 44618                  None  Jotstar
# 44619                  None  Jotstar

# %%
jotstar_content_consumption_df['platform'] = 'Jotstar'
liocinema_content_consumption_df['platform'] = 'LioCinema'

# %%
content_consumption_df = pd.concat([liocinema_content_consumption_df, jotstar_content_consumption_df])

# %%
content_consumption_df.head()
# Out:
#             user_id device_type  total_watch_time_mins   platform
# 0  UIDLC459c98ee486      Mobile                    502  LioCinema
# 1  UIDLCe4b2fd90790      Mobile                   2098  LioCinema
# 2  UIDLCbc8f0a05367      Mobile                    557  LioCinema
# 3  UIDLC9fc67130445      Mobile                   1720  LioCinema
# 4  UIDLC7026c3e0374      Mobile                    908  LioCinema

# %%
content_consumption_df.tail()
# Out:
#                  user_id device_type  total_watch_time_mins platform
# 133855  UIDJS96f8e4a1b54      Laptop                  11671  Jotstar
# 133856  UIDJSa131c0a6199      Laptop                   9453  Jotstar
# 133857  UIDJS3f8a556df56      Laptop                    199  Jotstar
# 133858  UIDJS7a51d1c2bcd      Laptop                   3252  Jotstar
# 133859  UIDJS44e851ffbd2      Laptop                  11574  Jotstar

# %%
content_df['content_id'].isnull().sum() == 0
# Out:
# True

# %%
content_df['content_id'].duplicated().sum()
# Out:
# 0

# %%
subscribers_df['user_id'].isnull().sum() == 0
# Out:
# True

# %%
subscribers_df['user_id'].duplicated().sum()
# Out:
# 0

# %%
content_consumption_df['user_id'].duplicated().sum()
# Out:
# 336546

# %%
content_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3610 entries, 0 to 2359
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   content_id    3610 non-null   object
#  1   content_type  3610 non-null   object
#  2   language      3610 non-null   object
#  3   genre         3610 non-null   object
#  4   run_time      3610 non-null   int64
#  5   platform      3610 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 197.4+ KB

# %%
subscribers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228066 entries, 0 to 44619
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                228066 non-null  object
#  1   age_group              228066 non-null  object
#  2   city_tier              228066 non-null  object
#  3   subscription_date      228066 non-null  object
#  4   subscription_plan      228066 non-null  object
#  5   last_active_date       88957 non-null   object
#  6   plan_change_date       32104 non-null   object
#  7   new_subscription_plan  32104 non-null   object
#  8   platform               228066 non-null  object
# dtypes: object(9)
# memory usage: 17.4+ MB

# %% [markdown]
# content_consumption_df.info()

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assume df is your DataFrame with all categorical columns
categorical_cols = content_df.drop(columns = ['content_id', 'run_time'])
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=content_df, x=col, order=content_df[col].value_counts().index)
    plt.title(f'Countplot for {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
categorical_cols = subscribers_df.drop(columns = ['user_id','subscription_date','last_active_date','plan_change_date','new_subscription_plan'])
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=subscribers_df, x=col, order=subscribers_df[col].value_counts().index)
    plt.title(f'Countplot for {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=subscribers_df, x=col, order=subscribers_df['new_subscription_plan'].value_counts().index)
plt.title(f'Countplot for New Subscription Plan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
numerical_cols = ['run_time']
for i, col in enumerate(numerical_cols):
    sns.histplot(content_df[col], kde = True)
    plt.title(f'Histplot for {col}')
    plt.tight_layout()
    plt.show()

# %%
numerical_cols = ['total_watch_time_mins']
for i, col in enumerate(numerical_cols):
    sns.histplot(content_consumption_df[col], kde = True)
    plt.title(f'Histplot for {col}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(content_df['content_type'], content_df['run_time'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Content Type vs Run time\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(content_df['language'], content_df['run_time'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Language vs Run time\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(content_df['genre'], content_df['run_time'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Genre vs Run time\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(content_df['content_type'], content_df['genre'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Content Type vs Genre\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['age_group'], subscribers_df['subscription_plan'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Age Group vs Subscription Plan\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['city_tier'], subscribers_df['subscription_plan'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'City Tier vs Subscription Plan\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['age_group'], subscribers_df['city_tier'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Age Group vs City Tier\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['age_group'], subscribers_df['new_subscription_plan'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Age Group vs New Subscription Plan\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['city_tier'], subscribers_df['new_subscription_plan'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'City Tier vs New Subscription Plan\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import numpy as np

# Create a crosstab
ct = pd.crosstab(subscribers_df['age_group'], subscribers_df['city_tier'])

# Calculate Cramér’s V
chi2, p, dof, ex = chi2_contingency(ct)
n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(ct, annot=True, cmap='Blues', fmt='d')
plt.title(f'Age Group vs City Tier\nCramér’s V: {cramers_v:.2f}')
plt.show()

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Example connection string
user = 'root'
password = 'Giri@14102003'
host = '127.0.0.1'  # or your MySQL server IP
port = 3306
database = 'Lio_Jotstar_db'

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

# %%
content_df.to_sql(
    name='contents',      # Name for the new table
    con=engine,
    if_exists='replace',      # Use 'append' to add to existing table
    index=False,
    chunksize = 400000,
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File D:\Codes\Python\Lib\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File D:\Codes\Python\Lib\socket.py:828, in create_connection(address, timeout, source_address, all_errors)
#     827 exceptions = []
# --> 828 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     829     af, socktype, proto, canonname, sa = res
#
# File D:\Codes\Python\Lib\socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# ...
